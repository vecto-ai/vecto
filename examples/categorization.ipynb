# %% [markdown]
# ### Import modules

# %%
import sys
sys.path.insert(0, '../../vecto/')

# %%
from vecto.benchmarks.categorization import *
import vecto.embeddings

# %% [markdown]
# ### Load embeddings

# %%
embeddings = vecto.embeddings.load_from_dir('../../../temp/')

# %% [markdown]
# ### Run categorization

# %%
categorization = KMeansCategorization()

# %%
categorization.get_result(embeddings, '../tests/data/benchmarks/categorization')
# Out:
# [(defaultdict(<function vecto.benchmarks.categorization.categorization.KMeansCategorization.collect_stats.<locals>.<lambda>()>,
#               {'0. suggest': {'true_category': 'communication-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '1. talk': {'true_category': 'communication-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '2. speak': {'true_category': 'communication-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '3. request': {'true_category': 'communication-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '4. read': {'true_category': 'communication-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '5. evaluate': {'true_category': 'mentalState-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '6. remember': {'true_category': 'mentalState-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '7. know': {'true_category': 'mentalState-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '8. forget': {'true_category': 'mentalState-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '9. check': {'true_category': 'mentalState-cognition',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '10. run': {'true_category': 'motionManner-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '11. fly': {'true_category': 'motionManner-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '12. drive': {'true_category': 'motionManner-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '13. walk': {'true_category': 'motionManner-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '14. ride': {'true_category': 'motionManner-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '15. arrive': {'true_category': 'motionDirection-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '16. enter': {'true_category': 'motionDirection-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '17. fall': {'true_category': 'motionDirection-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '18. rise': {'true_category': 'motionDirection-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '19. leave': {'true_category': 'motionDirection-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '20. carry': {'true_category': 'changeLocation-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'true',
#                 'distance_to_centroid': 0.2665716670392624},
#                '21. push': {'true_category': 'changeLocation-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'true',
#                 'distance_to_centroid': 0.48047876933368816},
#                '22. move': {'true_category': 'changeLocation-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'true',
#                 'distance_to_centroid': 0.3384229005601471},
#                '23. send': {'true_category': 'changeLocation-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'true',
#                 'distance_to_centroid': 0.14853417662571977},
#                '24. pull': {'true_category': 'changeLocation-motion',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'true',
#                 'distance_to_centroid': 0.39257215988642447},
#                '25. listen': {'true_category': 'bodySense-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '26. smell': {'true_category': 'bodySense-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '27. feel': {'true_category': 'bodySense-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '28. look': {'true_category': 'bodySense-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '29. notice': {'true_category': 'bodySense-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '30. eat': {'true_category': 'bodyAction-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '31. breathe': {'true_category': 'bodyAction-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '32. drink': {'true_category': 'bodyAction-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '33. smile': {'true_category': 'bodyAction-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '34. cry': {'true_category': 'bodyAction-body',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '35. acquire': {'true_category': 'exchange-exchange',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '36. lend': {'true_category': 'exchange-exchange',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '37. buy': {'true_category': 'exchange-exchange',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '38. sell': {'true_category': 'exchange-exchange',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '39. pay': {'true_category': 'exchange-exchange',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447},
#                '40. kill': {'true_category': 'changeState-changeState',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.2665716670392624},
#                '41. destroy': {'true_category': 'changeState-changeState',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.48047876933368816},
#                '42. repair': {'true_category': 'changeState-changeState',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.3384229005601471},
#                '43. die': {'true_category': 'changeState-changeState',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.14853417662571977},
#                '44. break': {'true_category': 'changeState-changeState',
#                 'predicted_category': 'changeLocation-motion',
#                 'hit': 'false',
#                 'distance_to_centroid': 0.39257215988642447}}),
#   {'inertia': 20.903010061180314,
#    'params': "{'algorithm': 'auto', 'copy_x': True, 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'n_jobs': 1, 'precompute_distances': 'auto', 'random_state': None, 'tol': 0.0001, 'verbose': 0}",
#    'scores': {'Purity': 0.69,
#     'Ari': 0.36,
#     'Homogeneity': 0.68,
#     'Completeness': 0.65,
#     'V-measure': 0.66,
#     'Mutual info': 1.42,
#     'Fowlkes-Mallows': 0.43}})]
